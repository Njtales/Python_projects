# %% [markdown]
# ## Rock Paper Scissor python

# %%
import random

input("Welcome to Rock, Paper, Scissors! Press Enter to start.")

user_wins = 0
computer_wins = 0

choices = ["rock", "paper", "scissors"]

while True:
    random_idx = random.randint(0,2)
    cpu_choice = choices[random_idx]

    user_choice = input("Rock, Paper, or Scissors? ").lower()
    while user_choice not in choices:
        user_choice = input("That is not a valid choice. Please try again: ").lower()
    
    print("Your choice:", user_choice)
    print("Computer's choice:", cpu_choice)

    if user_choice == 'rock':
        if cpu_choice == 'rock':
            print("It's a tie!")
        elif cpu_choice == 'scissors':
            print("You win!")
            user_wins += 1
        elif cpu_choice == 'paper':
            print("You lose!")
            computer_wins += 1
    elif user_choice == 'paper':
        if cpu_choice == 'paper':
            print("It's a tie!")
        elif cpu_choice == 'rock':
            print("You win!")
            user_wins += 1
        elif cpu_choice == 'scissors':
            print("You lose!")
            computer_wins += 1
    elif user_choice == 'scissors':
        if cpu_choice == 'scissors':
            print("It's a tie!")
        elif cpu_choice == 'paper':
            print("You win!")
            user_wins += 1
        elif cpu_choice == 'rock':
            print("You lose!")
            computer_wins += 1

    print("\nYou have "+str(user_wins)+" wins")
    print("The computer has "+str(computer_wins)+" wins")
    
    repeat = input("Play again? (Y/N) ").lower()
    while repeat not in ['y', 'n']:
        repeat = input("That is not a valid choice. Please try again: ").lower()
  
    if repeat == 'n':
        break

    print("\n----------------------------\n")
# Out:
# Welcome to Rock, Paper, Scissors! Press Enter to start.
# Rock, Paper, or Scissors? rock
# Your choice: rock
# Computer's choice: paper
# You lose!
# You have 0 wins
# The computer has 1 wins
# Play again? (Y/N) y
#
# ----------------------------
#
# Rock, Paper, or Scissors? paper
# Your choice: paper
# Computer's choice: rock
# You win!
# You have 1 wins
# The computer has 1 wins
# Play again? (Y/N) y
#
# ----------------------------
#
# Rock, Paper, or Scissors? scissor
# That is not a valid choice. Please try again: scissors
# Your choice: scissors
# Computer's choice: paper
# You win!
# You have 2 wins
# The computer has 1 wins
# Play again? (Y/N) y
#
# ----------------------------
#
# Rock, Paper, or Scissors? paper
# Your choice: paper
# Computer's choice: scissors
# You lose!
# You have 2 wins
# The computer has 2 wins
# Play again? (Y/N) y
#
# ----------------------------
#
# Rock, Paper, or Scissors? rock
# Your choice: rock
# Computer's choice: paper
# You lose!
# You have 2 wins
# The computer has 3 wins
# Play again? (Y/N) y
#
# ----------------------------
#
# Rock, Paper, or Scissors? scissor
# That is not a valid choice. Please try again: scissors
# Your choice: scissors
# Computer's choice: rock
# You lose!
# You have 2 wins
# The computer has 4 wins
# Play again? (Y/N) y
#
# ----------------------------
#
# Rock, Paper, or Scissors? rock
# Your choice: rock
# Computer's choice: paper
# You lose!
# You have 2 wins
# The computer has 5 wins
# Play again? (Y/N) y
#
# ----------------------------
#
# Rock, Paper, or Scissors? paper
# Your choice: paper
# Computer's choice: paper
# It's a tie!
# You have 2 wins
# The computer has 5 wins
# Play again? (Y/N) y
#
# ----------------------------
#
# Rock, Paper, or Scissors? paper
# Your choice: paper
# Computer's choice: rock
# You win!
# You have 3 wins
# The computer has 5 wins
# Play again? (Y/N) y
#
# ----------------------------
#
# Rock, Paper, or Scissors? paper
# Your choice: paper
# Computer's choice: scissors
# You lose!
# You have 3 wins
# The computer has 6 wins
# Play again? (Y/N) y
#
# ----------------------------
#
# Rock, Paper, or Scissors? rock
# Your choice: rock
# Computer's choice: paper
# You lose!
# You have 3 wins
# The computer has 7 wins
# Play again? (Y/N) n
